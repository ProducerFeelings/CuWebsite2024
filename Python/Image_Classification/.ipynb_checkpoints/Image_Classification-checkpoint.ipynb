# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

# %%
data_train_path = 'Train'
data_test_path = 'Test'
data_val_path = 'Validation'

# %%
img_width = 180
img_height = 180

# %%
data_train = tf.keras.utils.image_dataset_from_directory(
    data_train_path ,
    shuffle=True,
    image_size=(img_width, img_height),
    batch_size=32,
    validation_split=False)
# Out:
# Found 25 files belonging to 3 classes.

# %%
data_Cu = data_train.class_names

# %%
data_val = tf.keras.utils.image_dataset_from_directory(data_val_path, image_size=(img_height, img_width),  batch_size=32, shuffle=False, validation_split=False)
# Out:
# Found 6 files belonging to 2 classes.

# %%
data_test = tf.keras.utils.image_dataset_from_directory(data_test_path, image_size=(img_height,img_width),shuffle=False,batch_size=32, validation_split=False)
# Out:
# Found 9 files belonging to 2 classes.

# %%
plt.figure(figsize=(10,10))
for image, labels in data_train.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(data_Cu[labels[i]])
        plt.axis('off')

# %%
from tensorflow.keras.models import Sequential

# %%
data_train
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
from tensorflow.keras import Sequential
from tensorflow.keras import layers

# %%
model = Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32,3, padding='same', activation='relu'),
                  layers.MaxPool2D(),
                  layers.Conv2D(64,3, padding='same', activation='relu'),
                  layers.MaxPooling2D(),
                  layers.Flatten(),
                  layers.Dropout(0.2),
                  layers.Dense(128),
                  layers.Dense(units = len(data_Cu))

                  
 

])

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
epochs_size = 25
history = model.fit(data_train, validation_data = data_val, epochs=epochs_size,)
# Out:
# Epoch 1/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.5200 - loss: 1.0569 - val_accuracy: 1.0000 - val_loss: 2.2848e-06
# Epoch 2/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - accuracy: 0.7600 - loss: 3.3741 - val_accuracy: 1.0000 - val_loss: 1.0534e-04
# Epoch 3/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.7600 - loss: 2.4073 - val_accuracy: 1.0000 - val_loss: 0.0244
# Epoch 4/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.7600 - loss: 1.0964 - val_accuracy: 0.3333 - val_loss: 0.8137
# Epoch 5/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - accuracy: 0.5200 - loss: 1.0469 - val_accuracy: 0.3333 - val_loss: 0.8568
# Epoch 6/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.5200 - loss: 0.9508 - val_accuracy: 1.0000 - val_loss: 0.3795
# Epoch 7/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.9200 - loss: 0.5654 - val_accuracy: 1.0000 - val_loss: 0.0970
# Epoch 8/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.7600 - loss: 0.4635 - val_accuracy: 1.0000 - val_loss: 0.0506
# Epoch 9/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.7600 - loss: 0.4862 - val_accuracy: 1.0000 - val_loss: 0.0840
# Epoch 10/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.7600 - loss: 0.3969 - val_accuracy: 1.0000 - val_loss: 0.1562
# Epoch 11/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.8000 - loss: 0.3336 - val_accuracy: 1.0000 - val_loss: 0.2201
# Epoch 12/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 1.0000 - loss: 0.3121 - val_accuracy: 1.0000 - val_loss: 0.2304
# Epoch 13/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 1.0000 - loss: 0.2857 - val_accuracy: 1.0000 - val_loss: 0.1860
# Epoch 14/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - accuracy: 1.0000 - loss: 0.2273 - val_accuracy: 1.0000 - val_loss: 0.1169
# Epoch 15/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 571ms/step - accuracy: 1.0000 - loss: 0.1776 - val_accuracy: 1.0000 - val_loss: 0.0749
# Epoch 16/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 1.0000 - loss: 0.1554 - val_accuracy: 1.0000 - val_loss: 0.0693
# Epoch 17/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step - accuracy: 1.0000 - loss: 0.1139 - val_accuracy: 1.0000 - val_loss: 0.0742
# Epoch 18/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - accuracy: 1.0000 - loss: 0.0870 - val_accuracy: 1.0000 - val_loss: 0.0759
# Epoch 19/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 538ms/step - accuracy: 1.0000 - loss: 0.0712 - val_accuracy: 1.0000 - val_loss: 0.0590
# Epoch 20/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step - accuracy: 1.0000 - loss: 0.0529 - val_accuracy: 1.0000 - val_loss: 0.0313
# Epoch 21/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 1.0000 - loss: 0.0331 - val_accuracy: 1.0000 - val_loss: 0.0142
# Epoch 22/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step - accuracy: 1.0000 - loss: 0.0261 - val_accuracy: 1.0000 - val_loss: 0.0085
# Epoch 23/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 1.0000 - loss: 0.0191 - val_accuracy: 1.0000 - val_loss: 0.0074
# Epoch 24/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 1.0000 - val_loss: 0.0071
# Epoch 25/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 1.0000 - val_loss: 0.0064

# %%
epochs_range = range(epochs_size)
plt.figure(figsize=(8,8))

# First subplot for accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs_range, history.history['accuracy'], label='Training Accuracy')
plt.plot(epochs_range, history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.legend()

# Second subplot for loss
plt.subplot(1, 2, 2)
plt.plot(epochs_range, history.history['loss'], label='Training Loss')
plt.plot(epochs_range, history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.legend()

plt.show()

# %%
image = ''
image = tf.keras.utils.load_img(image, target_size=(img_height, img_width))
img_arr = tf.keras.utils.img_to_array(image)  # Corrected method name
img_bat = tf.expand_dims(img_arr, 0)  # Adding a batch dimension

# %%
predict = model.predict(img_bat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step

# %%
score = tf.nn.softmax(predict)

# %%
disease_name = data_Cu[np.argmax(score)]  # Get the disease name based on the highest score index
accuracy = np.max(score) * 100  # Calculate the accuracy as a percentage

print('Disease in image is {} with accuracy of {:.2f}%'.format(disease_name, accuracy))
# Out:
# Disease in image is Chronic Urticaria with accuracy of 99.85%
